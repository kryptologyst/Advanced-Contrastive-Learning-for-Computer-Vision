# %% [markdown]
# # Contrastive Learning Quick Start
#
# This notebook provides a quick introduction to the contrastive learning framework.
# We'll demonstrate how to train, evaluate, and visualize contrastive learning models.
